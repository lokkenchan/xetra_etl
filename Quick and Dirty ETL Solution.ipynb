# %%
import boto3
import pandas as pd
from io import StringIO, BytesIO
from datetime import datetime, timedelta

# %%
#Argument Date
# arg_date = '2022-05-07'

# %%
# arg_date_dt = datetime.strptime(arg_date,'%Y-%m-%d').date() - timedelta(days=1)

# %%
# arg_date_dt

# %%
s3 = boto3.resource('s3')
bucket = s3.Bucket('xetra-1234')

# %% [markdown]
# ## Reading Data

# %%
bucket_obj = bucket.objects.filter(Prefix='2022-01-28')
objects = [obj for obj in bucket_obj]

# %%
objects

# %%
csv_obj = bucket.Object(key='2022-01-28/2022-01-28_BINS_XETR13.csv').get().get('Body').read().decode('utf-8')

# %%
csv_obj

# %%
data = StringIO(csv_obj)
df = pd.read_csv(data, delimiter=',')

# %%
df

# %% [markdown]
# ## Reading Multiple Files

# %%
#Filter twice
bucket_obj1 = bucket.objects.filter(Prefix='2022-03-15')
bucket_obj2 = bucket.objects.filter(Prefix='2022-03-16')
#Combined list comprehensions
objects = [obj for obj in bucket_obj1] + [obj for obj in bucket_obj2]

# %%
objects

# %%
csv_obj_init = bucket.Object(key=objects[0].key).get().get('Body').read().decode('utf-8')
data = StringIO(csv_obj_init)
df_init = pd.read_csv(data,delimiter=',')

# %%
df_init.columns

# %%
df_list = []
df_all = pd.DataFrame(columns=df_init.columns)
for obj in objects:
    csv_obj = bucket.Object(key=obj.key).get().get('Body').read().decode('utf-8')
    data = StringIO(csv_obj)
    df = pd.read_csv(data, delimiter=',')
    df_list.append(df)
df_all = pd.concat(df_list) 
df_all=df_all.reset_index(drop=True)

# %%
df_all

# %%
#Selecting the columns of interest - 8 
columns = ['ISIN', 'Date', 'Time', 'StartPrice', 'MaxPrice', 'MinPrice',
       'EndPrice', 'TradedVolume']
df_all = df_all.loc[:,columns]

# %%
df_all.dropna(inplace=True)

# %%
df_all.shape

# %% [markdown]
# ## Transformations

# %% [markdown]
# ### Get opening price per ISIN and day

# %%
df_all

# %%
df_all['opening_price'] = df_all.sort_values(by=['Time']).groupby(['ISIN','Date'])['StartPrice'].transform('first')

# %%
df_all

# %%
df_all[df_all['ISIN']=='DE000A0LD6E6']

# %% [markdown]
# ### Get closing price per ISIN and day

# %%
df_all['closing_price'] = df_all.sort_values(by=['Time']).groupby(['ISIN','Date'])['StartPrice'].transform('last')

# %%
df_all[df_all['ISIN']=='DE000A0LD6E6']

# %% [markdown]
# ### Aggregations

# %%
df_all = df_all.groupby(['ISIN','Date'],as_index=False).agg(opening_price_eur=('opening_price','min'),closing_price_eur=('closing_price','min'), minimum_price_eur=('MinPrice','min'), maximum_price_eur=('MaxPrice','max'), daily_traded_volume=('TradedVolume','sum'))

# %%
df_all

# %% [markdown]
# ### Percent Change Prev Closing

# %%
df_all['prev_closing_price'] = df_all.sort_values(by=['Date']).groupby(['ISIN'])['closing_price_eur'].shift(1)

# %%
df_all

# %%
df_all['change_prev_closing_%'] = (df_all['closing_price_eur'] - df_all['prev_closing_price']) / df_all['prev_closing_price'] * 100

# %%
df_all.drop(columns=['prev_closing_price'],inplace=True)

# %%
df_all = df_all.round(decimals=2)

# %%
df_all

# %% [markdown]
# ## Argument Date

# %%
import boto3
import pandas as pd
from io import StringIO, BytesIO 
from datetime import datetime, timedelta

# %%
arg_date = '2022-05-07'

# %%
arg_date_dt = datetime.strptime(arg_date,'%Y-%m-%d').date() - timedelta(days=1)

# %%
arg_date_dt
# Out:
# datetime.date(2022, 5, 6)

# %%
s3 = boto3.resource('s3')
bucket = s3.Bucket('xetra-1234')

# %%
bucket_obj = bucket.objects.filter(Prefix='2022-01-28')
objects = [obj for obj in bucket_obj]

# %%
objects = [obj for obj in bucket.objects.all() if datetime.strptime(obj.key.split('/')[0], '%Y-%m-%d').date() >= arg_date_dt]

# %%
objects
# Out:
# [s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-06/2022-05-04_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-07/2022-05-07_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-08/2022-05-08_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-09/2022-05-09_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-10/2022-05-10_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-11/2022-05-11_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-12/2022-05-11_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-13/2022-05-11_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-14/2022-05-14_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-15/2022-05-15_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-16/2022-05-16_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-17/2022-05-17_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-18/2022-05-18_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-19/2022-05-18_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-20/2022-05-18_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-21/2022-05-21_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-22/2022-05-22_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-23/2022-05-23_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-24/2022-05-24_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-25/2022-05-25_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-26/2022-05-25_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-27/2022-05-25_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-28/2022-05-28_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-28/2022-05-28_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-28/2022-05-28_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-28/2022-05-28_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-05-28/2022-05-28_BINS_XETR04.csv'),
# ...
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-09/2022-06-09_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-10/2022-06-10_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-11/2022-06-11_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-12/2022-06-11_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-13/2022-06-11_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-14/2022-06-14_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR15.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR16.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR17.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR18.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR19.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR20.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR21.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR22.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-15/2022-06-15_BINS_XETR23.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR00.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR01.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR02.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR03.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR04.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR05.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR06.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR07.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR08.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR09.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR10.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR11.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR12.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR13.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR14.csv'),
#  s3.ObjectSummary(bucket_name='xetra-1234', key='2022-06-16/2022-06-16_BINS_XETR15.csv'),
#  ...]

# %%
len(objects)
# Out:
# 5697

# %%
csv_obj_init = bucket.Object(key=objects[0].key).get().get('Body').read().decode('utf-8')
data = StringIO(csv_obj_init)
df_init = pd.read_csv(data,delimiter=',')

# %%
df_init.columns
# Out:
# Index(['ISIN', 'Mnemonic', 'SecurityDesc', 'SecurityType', 'Currency',
#        'SecurityID', 'Date', 'Time', 'StartPrice', 'MaxPrice', 'MinPrice',
#        'EndPrice', 'TradedVolume', 'NumberOfTrades'],
#       dtype='object')

# %%
df_list = []
df_all = pd.DataFrame(columns=df_init.columns)

# %%
import time
count = 0
for obj in objects:
#     if obj is None: #comment out this valueerror
#         raise ValueError("My object should not be None")
    csv_obj = bucket.Object(key=obj.key).get().get('Body').read().decode('utf-8')
    count = count + 1
    print(f'Count: {count}', end='\r')
#     time.sleep(1) 
    data = StringIO(csv_obj)
    df = pd.read_csv(data, delimiter=',')
    df_list.append(df)
# Out:
# Count: 5697

# %%
df_all = pd.concat(df_list) 
df_all=df_all.reset_index(drop=True)

# %%
df_all
# Out:
#                   ISIN Mnemonic               SecurityDesc  SecurityType
# 0         AT0000A0E9W5     SANT                S+T AG O.N.  Common stock  \
# 1         DE000A0DJ6J9      S92       SMA SOLAR TECHNOL.AG  Common stock
# 2         DE000A0D6554     NDX1             NORDEX SE O.N.  Common stock
# 3         DE000A0D9PT0      MTX   MTU AERO ENGINES NA O.N.  Common stock
# 4         DE000A0HN5C6     DWNI     DEUTSCHE WOHNEN SE INH  Common stock
# ...                ...      ...                        ...           ...
# 28623178  GB00BLD4ZP54     CLTC    COINSHARES DIG.SEC.OEND           ETN
# 28623179  LU1923627332     RUSL  MUL-LYX.MSCI RUSSI.DIS.LS           ETF
# 28623180  US98956P1021      ZIM  ZIMMER BIOMET HLDGS DL-01  Common stock
# 28623181  US9224171002      VEO  VEECO INSTRUMENTS  DL-,01  Common stock
# 28623182  IT0005143547      EM8   ENERGICA MOTOR CO.S.P.A.  Common stock
#
#          Currency SecurityID        Date   Time  StartPrice  MaxPrice
# 0             EUR    2504159  2022-05-06  08:00      16.660    16.660  \
# 1             EUR    2504287  2022-05-06  08:00      30.620    30.620
# 2             EUR    2504290  2022-05-06  08:00      13.450    13.550
# 3             EUR    2504297  2022-05-06  08:00     187.350   187.700
# 4             EUR    2504314  2022-05-06  08:00      36.530    36.530
# ...           ...        ...         ...    ...         ...       ...
# 28623178      EUR    6479084  2022-12-31  16:46      19.324    19.324
# 28623179      EUR    5424594  2022-12-31  16:52      12.400    12.400
# 28623180      EUR    4582018  2022-12-31  20:30     113.100   113.100
# 28623181      EUR    6198311  2022-12-31  20:30      24.600    24.600
# 28623182      EUR    7026075  2022-12-31  20:30       3.100     3.100
#
#           MinPrice  EndPrice TradedVolume NumberOfTrades
# 0           16.660    16.660          915              1
# 1           30.620    30.620          236              1
# 2           13.380    13.530         8870             24
# 3          187.350   187.550         1857              9
# 4           36.530    36.530          198              1
# ...            ...       ...          ...            ...
# 28623178    19.324    19.324            0              2
# 28623179    12.400    12.400         2645              2
# 28623180   113.100   113.100            0              1
# 28623181    24.600    24.600            0              1
# 28623182     3.100     3.100            0              1
#
# [28623183 rows x 14 columns]

# %%
#Selecting the columns of interest - 8 
columns = ['ISIN', 'Date', 'Time', 'StartPrice', 'MaxPrice', 'MinPrice',
       'EndPrice', 'TradedVolume']
df_all = df_all.loc[:,columns]

# %%
df_all.dropna(inplace=True)

# %%
df_all.shape
# Out:
# (28623183, 8)

# %%
## Transformations
### Get opening price per ISIN and day
df_all
# Out:
#                   ISIN        Date   Time  StartPrice  MaxPrice  MinPrice
# 0         AT0000A0E9W5  2022-05-06  08:00      16.660    16.660    16.660  \
# 1         DE000A0DJ6J9  2022-05-06  08:00      30.620    30.620    30.620
# 2         DE000A0D6554  2022-05-06  08:00      13.450    13.550    13.380
# 3         DE000A0D9PT0  2022-05-06  08:00     187.350   187.700   187.350
# 4         DE000A0HN5C6  2022-05-06  08:00      36.530    36.530    36.530
# ...                ...         ...    ...         ...       ...       ...
# 28623178  GB00BLD4ZP54  2022-12-31  16:46      19.324    19.324    19.324
# 28623179  LU1923627332  2022-12-31  16:52      12.400    12.400    12.400
# 28623180  US98956P1021  2022-12-31  20:30     113.100   113.100   113.100
# 28623181  US9224171002  2022-12-31  20:30      24.600    24.600    24.600
# 28623182  IT0005143547  2022-12-31  20:30       3.100     3.100     3.100
#
#           EndPrice TradedVolume
# 0           16.660          915
# 1           30.620          236
# 2           13.530         8870
# 3          187.550         1857
# 4           36.530          198
# ...            ...          ...
# 28623178    19.324            0
# 28623179    12.400         2645
# 28623180   113.100            0
# 28623181    24.600            0
# 28623182     3.100            0
#
# [28623183 rows x 8 columns]

# %%
df_all['opening_price'] = df_all.sort_values(by=['Time']).groupby(['ISIN','Date'])['StartPrice'].transform('first')

# %%
df_all[df_all['ISIN']=='DE000A0LD6E6']
# Out:
#                   ISIN        Date   Time  StartPrice  MaxPrice  MinPrice
# 7         DE000A0LD6E6  2022-05-06  08:00       79.50     79.50     79.40  \
# 164       DE000A0LD6E6  2022-05-06  08:01       79.40     79.40     79.40
# 500       DE000A0LD6E6  2022-05-06  08:03       79.50     79.65     79.50
# 2913      DE000A0LD6E6  2022-05-06  08:05       79.45     79.45     79.45
# 3237      DE000A0LD6E6  2022-05-06  08:06       79.50     79.50     79.45
# ...                ...         ...    ...         ...       ...       ...
# 28618377  DE000A0LD6E6  2022-12-31  16:26       64.55     64.60     64.50
# 28618744  DE000A0LD6E6  2022-12-31  16:27       64.50     64.50     64.50
# 28619053  DE000A0LD6E6  2022-12-31  16:28       64.45     64.55     64.45
# 28619405  DE000A0LD6E6  2022-12-31  16:29       64.50     64.50     64.50
# 28619982  DE000A0LD6E6  2022-12-31  16:35       64.50     64.50     64.50
#
#           EndPrice TradedVolume  opening_price
# 7            79.50          766           79.5
# 164          79.40           25           79.5
# 500          79.65          492           79.5
# 2913         79.45          160           79.5
# 3237         79.45           75           79.5
# ...            ...          ...            ...
# 28618377     64.50         1967           65.0
# 28618744     64.50          128           65.0
# 28619053     64.55          485           65.0
# 28619405     64.50           85           65.0
# 28619982     64.50        75266           65.0
#
# [69950 rows x 9 columns]

# %%
### Get closing price per ISIN and day
df_all['closing_price'] = df_all.sort_values(by=['Time']).groupby(['ISIN','Date'])['StartPrice'].transform('last')

# %%
df_all[df_all['ISIN']=='DE000A0LD6E6']
# Out:
#                   ISIN        Date   Time  StartPrice  MaxPrice  MinPrice
# 7         DE000A0LD6E6  2022-05-06  08:00       79.50     79.50     79.40  \
# 164       DE000A0LD6E6  2022-05-06  08:01       79.40     79.40     79.40
# 500       DE000A0LD6E6  2022-05-06  08:03       79.50     79.65     79.50
# 2913      DE000A0LD6E6  2022-05-06  08:05       79.45     79.45     79.45
# 3237      DE000A0LD6E6  2022-05-06  08:06       79.50     79.50     79.45
# ...                ...         ...    ...         ...       ...       ...
# 28618377  DE000A0LD6E6  2022-12-31  16:26       64.55     64.60     64.50
# 28618744  DE000A0LD6E6  2022-12-31  16:27       64.50     64.50     64.50
# 28619053  DE000A0LD6E6  2022-12-31  16:28       64.45     64.55     64.45
# 28619405  DE000A0LD6E6  2022-12-31  16:29       64.50     64.50     64.50
# 28619982  DE000A0LD6E6  2022-12-31  16:35       64.50     64.50     64.50
#
#           EndPrice TradedVolume  opening_price  closing_price
# 7            79.50          766           79.5           79.0
# 164          79.40           25           79.5           79.0
# 500          79.65          492           79.5           79.0
# 2913         79.45          160           79.5           79.0
# 3237         79.45           75           79.5           79.0
# ...            ...          ...            ...            ...
# 28618377     64.50         1967           65.0           64.5
# 28618744     64.50          128           65.0           64.5
# 28619053     64.55          485           65.0           64.5
# 28619405     64.50           85           65.0           64.5
# 28619982     64.50        75266           65.0           64.5
#
# [69950 rows x 10 columns]

# %%
### Aggregations
df_all = df_all.groupby(['ISIN','Date'],as_index=False).agg(opening_price_eur=('opening_price','min'),closing_price_eur=('closing_price','min'), minimum_price_eur=('MinPrice','min'), maximum_price_eur=('MaxPrice','max'), daily_traded_volume=('TradedVolume','sum'))

# %%
### Percent Change Prev Closing
df_all['prev_closing_price'] = df_all.sort_values(by=['Date']).groupby(['ISIN'])['closing_price_eur'].shift(1)

# %%
df_all['change_prev_closing_%'] = (df_all['closing_price_eur'] - df_all['prev_closing_price']) / df_all['prev_closing_price'] * 100

# %%
df_all.drop(columns=['prev_closing_price'],inplace=True)

# %%
df_all = df_all.round(decimals=2)

# %%
#Filtering by date
df_all =df_all[df_all.Date>=arg_date]

# %%
df_all
# Out:
#                 ISIN        Date  opening_price_eur  closing_price_eur
# 1       AT000000STR1  2022-05-07              38.65              38.25  \
# 2       AT000000STR1  2022-05-08              38.75              38.75
# 3       AT000000STR1  2022-05-09              39.00              38.60
# 4       AT000000STR1  2022-05-10              38.95              38.95
# 5       AT000000STR1  2022-05-11              39.15              39.25
# ...              ...         ...                ...                ...
# 768136  XS2434891219  2022-12-27               3.44               3.50
# 768137  XS2434891219  2022-12-28               3.44               3.66
# 768138  XS2434891219  2022-12-29               3.44               3.66
# 768139  XS2434891219  2022-12-30               3.44               3.66
# 768140  XS2434891219  2022-12-31               3.44               3.66
#
#         minimum_price_eur  maximum_price_eur daily_traded_volume
# 1                   38.25              38.65                 410  \
# 2                   38.50              38.75                 251
# 3                   38.50              39.05                 905
# 4                   38.95              39.45                 147
# 5                   38.65              39.60                 914
# ...                   ...                ...                 ...
# 768136               3.44               3.50                   0
# 768137               3.42               3.66                   0
# 768138               3.42               3.66                   0
# 768139               3.42               3.66                   0
# 768140               3.42               3.66                   0
#
#         change_prev_closing_%
# 1                       -1.67
# 2                        1.31
# 3                       -0.39
# 4                        0.91
# 5                        0.77
# ...                       ...
# 768136                   0.00
# 768137                   4.53
# 768138                   0.00
# 768139                   0.00
# 768140                   0.00
#
# [764956 rows x 8 columns]

# %% [markdown]
# ## Saving to S3

# %%
#You need to create a S3 bucket in AWS with a unique name
key = 'xetra_daily_report_' + datetime.today().strftime("%Y%m%d_%H%M%S") + '.parquet'

# %%
out_buffer = BytesIO()
df_all.to_parquet(out_buffer,index=False)
bucket_target = s3.Bucket('xetra-data-etl-destination') #own bucket name
bucket_target.put_object(Body=out_buffer.getvalue(),Key=key)
# Out:
# s3.Object(bucket_name='xetra-data-etl-destination', key='xetra_daily_report_20230422_151559.parquet')

# %% [markdown]
# ### Reading the uploaded file

# %%
for obj in bucket_target.objects.all():
    print(obj.key)
# Out:
# xetra_daily_report_20230422_151559.parquet

# %%
prq_obj = bucket_target.Object(key='xetra_daily_report_20230422_151559.parquet').get().get('Body').read()
data = BytesIO(prq_obj)
df_report = pd.read_parquet(data)

# %%
df_report
# Out:
#                 ISIN        Date  opening_price_eur  closing_price_eur
# 0       AT000000STR1  2022-05-07              38.65              38.25  \
# 1       AT000000STR1  2022-05-08              38.75              38.75
# 2       AT000000STR1  2022-05-09              39.00              38.60
# 3       AT000000STR1  2022-05-10              38.95              38.95
# 4       AT000000STR1  2022-05-11              39.15              39.25
# ...              ...         ...                ...                ...
# 764951  XS2434891219  2022-12-27               3.44               3.50
# 764952  XS2434891219  2022-12-28               3.44               3.66
# 764953  XS2434891219  2022-12-29               3.44               3.66
# 764954  XS2434891219  2022-12-30               3.44               3.66
# 764955  XS2434891219  2022-12-31               3.44               3.66
#
#         minimum_price_eur  maximum_price_eur  daily_traded_volume
# 0                   38.25              38.65                  410  \
# 1                   38.50              38.75                  251
# 2                   38.50              39.05                  905
# 3                   38.95              39.45                  147
# 4                   38.65              39.60                  914
# ...                   ...                ...                  ...
# 764951               3.44               3.50                    0
# 764952               3.42               3.66                    0
# 764953               3.42               3.66                    0
# 764954               3.42               3.66                    0
# 764955               3.42               3.66                    0
#
#         change_prev_closing_%
# 0                       -1.67
# 1                        1.31
# 2                       -0.39
# 3                        0.91
# 4                        0.77
# ...                       ...
# 764951                   0.00
# 764952                   4.53
# 764953                   0.00
# 764954                   0.00
# 764955                   0.00
#
# [764956 rows x 8 columns]
